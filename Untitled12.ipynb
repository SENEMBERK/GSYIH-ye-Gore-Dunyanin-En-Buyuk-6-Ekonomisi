# %% [markdown]
# # GSYİH'ye Göre Dünyanın En Büyük 6 Ekonomisi
#              **ABD, Çin, Japonya, Almanya, Birleşik Krallık, Hindistan

# %% [markdown]
# **Bu veri seti, ABD, Çin, Japonya, Almanya, Birleşik Krallık ve Hindistan'ı içeren dünyanın en büyük 6 Ekonomisinin (GSYİH'ye göre) 1990 ile 2020 arasındaki 30 yıllık zaman aralığına ilişkin temel göstergelere ilişkin verileri içerir.

# %%
**GÖSTERGELER;
**GSYİH'si en yüksek ülke $
**GSYİH uluslararası en yüksek ülke
**GSYİH uluslararası en yüksek ülke
**Toplam rezervler (altını içerir, cari ABD doları
**Nüfus, yıllık toplam**
**Nüfus, yıllık toplam**

# %% [markdown]
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# %matplotlib inline

# %%
usa=pd.read_csv("USA.csv")
usa.head(6)
# Out:
#     Country Name Country Code  \
# 0  United States          USA
# 1  United States          USA
# 2  United States          USA
# 3  United States          USA
# 4  United States          USA
# 5  United States          USA
#
#                                       Indicator Name     Indicator Code  \
# 0  Internally displaced persons, new displacement...        VC.IDP.NWCV
# 1  Merchandise exports to low- and middle-income ...  TX.VAL.MRCH.R2.ZS
# 2       Net barter terms of trade index (2000 = 100)  TT.PRI.MRCH.XD.WD
# 3  Merchandise imports from high-income economies...  TM.VAL.MRCH.HI.ZS
# 4  Share of tariff lines with international peaks...  TM.TAX.TCOM.IP.ZS
# 5  Share of tariff lines with international peaks...  TM.TAX.MANF.IP.ZS
#
#         1960       1961       1962       1963       1964       1965  ...  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN  ...
# 1   0.866813   0.968558   1.272206   1.306122   1.061018   0.763476  ...
# ...

# %% [markdown]
# **Veri Yükleme
# Bir ülkenin Ekonomisine ilişkin 1000'den fazla gösterge hakkında veri içeren dünya bankası veri web sitesinden indirilen ham csv dosyasını yükleme
# Burada ham csv dosyasını preprocessed_df() işlevine geçirin ve işlevi GDP'ye göre dünyadaki tüm ilk 6 Ekonomi için bir değişkene kaydedin.

# %%
usa=preprocessed_df(csvfile="USA.csv")

china=preprocessed_df(csvfile="China.csv")

japan=preprocessed_df(csvfile="Japan.csv")

germany=preprocessed_df(csvfile="Germany.csv")

united_kingdom=preprocessed_df(csvfile="United_Kingdom.csv")

india=preprocessed_df(csvfile="India.csv")

# %% [markdown]
# **Altı ülke yi tek bir veri çerçevesine yatay olarak birleştirelim..

# %% [markdown]
# **pandas concat() işlevini kullanarak altı veri çerçevesini tek bir veri çerçevesinde birleştirim ve liste yöntemini kullanarak ülkeleri listesini döngüye sokalım

# %% [markdown]
# **ülke adlarının listesi

# %%
countries=[usa,china,japan,germany,united_kingdom,india]

top_six=pd.concat([country[req_cols] for country in countries],axis=0)

# %%
top_six
# Out:
#      Country Name  Year     GDP (current US$)  \
# 33  United States  1991       6158129000000.0
# 34  United States  1992       6520327000000.0
# 35  United States  1993       6858559000000.0
# 36  United States  1994       7287236000000.0
# 37  United States  1995       7639749000000.0
# ..            ...   ...                   ...
# 58          India  2016  2294797980509.009766
# 59          India  2017  2651472946374.910156
# 60          India  2018  2702929718960.459961
# 61          India  2019  2831552222519.990234
# 62          India  2020  2667687951796.560059
#
#    GDP, PPP (current international $) GDP per capita (current US$)  \
# 33                    6158129000000.0                 24342.258905
# 34                    6520327000000.0                 25418.990776
# 35                    6858559000000.0                 26387.293734
# 36                    7287236000000.0                 27694.853416
# 37                    7639749000000.0                 28690.875701
# ...

# %% [markdown]
# **top_six veri çerçevesi 17 sütun (15 tanesi ekonomik göstergelerdir) ve 180 satır içerir
# her ülkenin 30 satırı vardır (30 yıl) toplam=6 ülke * 30 yıl = 180))

# %%
top_six.shape
# Out:
# (180, 17)

# %% [markdown]
# **'top_six' olan son veri çerçevesini 'top_six_economies.csv' adlı yeni bir csv dosyasına yazmak

# %%
top_six.to_csv('top_six_economies.csv')

# %%
df = pd.read_csv('top_six_economies.csv')

# %%
df.head()
# Out:
#    Unnamed: 0   Country Name  Year  GDP (current US$)  \
# 0          33  United States  1991       6.158129e+12
# 1          34  United States  1992       6.520327e+12
# 2          35  United States  1993       6.858559e+12
# 3          36  United States  1994       7.287236e+12
# 4          37  United States  1995       7.639749e+12
#
#    GDP, PPP (current international $)  GDP per capita (current US$)  \
# 0                        6.158129e+12                  24342.258905
# 1                        6.520327e+12                  25418.990776
# 2                        6.858559e+12                  26387.293734
# 3                        7.287236e+12                  27694.853416
# 4                        7.639749e+12                  28690.875701
#
#    GDP growth (annual %)  Imports of goods and services (% of GDP)  \
# 0              -0.108265                                 10.125543
# 1               3.522441                                 10.241680
# ...

# %% [markdown]
#  **GSYİH'si en yüksek ülke $

# %%
plt_1 = plt.figure(figsize=(10,8))
plt.xlabel('Country Names')
plt.ylabel('GDP $')
plt.title('highest country have GDP $')
plt.bar(df['Country Name'],df['GDP (current US$)'])
# Out:
# <BarContainer object of 180 artists>

# %% [markdown]
# **GSYİH uluslararası en yüksek ülke $

# %%
plt_1 = plt.figure(figsize=(10,8))
plt.xlabel('Country Names')
plt.ylabel('GDP international')
plt.title('highest country have GDP international')
plt.bar(df['Country Name'],df['GDP, PPP (current international $)'])
# Out:
# <BarContainer object of 180 artists>

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Country Name', 'Year', 'GDP (current US$)',
#        'GDP, PPP (current international $)', 'GDP per capita (current US$)',
#        'GDP growth (annual %)', 'Imports of goods and services (% of GDP)',
#        'Exports of goods and services (% of GDP)',
#        'Central government debt, total (% of GDP)',
#        'Total reserves (includes gold, current US$)',
#        'Unemployment, total (% of total labor force) (modeled ILO estimate)',
#        'Inflation, consumer prices (annual %)',
#        'Personal remittances, received (% of GDP)', 'Population, total',
#        'Population growth (annual %)',
#        'Life expectancy at birth, total (years)',
#        'Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)'],
#       dtype='object')

# %% [markdown]
# **GSYİH uluslararası en yüksek ülke

# %%
plt_1 = plt.figure(figsize=(10,8))
plt.xlabel('Country Names')
plt.ylabel('GDP international')
plt.title('highest country have GDP international')
plt.bar(df['Country Name'],df['Population, total'])
# Out:
# <BarContainer object of 180 artists>

# %%
df[['Population, total','Country Name']].groupby(['Country Name'],as_index=False).mean().sort_values(by='Population, total',ascending=False)
# Out:
#      Country Name  Population, total
# 0           China       1.299286e+09
# 2           India       1.148609e+09
# 5   United States       2.954754e+08
# 3           Japan       1.268171e+08
# 1         Germany       8.187303e+07
# 4  United Kingdom       6.138515e+07

# %% [markdown]
# **yüksek ülke en büyük nüfusa sahip

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Country Name', 'Year', 'GDP (current US$)',
#        'GDP, PPP (current international $)', 'GDP per capita (current US$)',
#        'GDP growth (annual %)', 'Imports of goods and services (% of GDP)',
#        'Exports of goods and services (% of GDP)',
#        'Central government debt, total (% of GDP)',
#        'Total reserves (includes gold, current US$)',
#        'Unemployment, total (% of total labor force) (modeled ILO estimate)',
#        'Inflation, consumer prices (annual %)',
#        'Personal remittances, received (% of GDP)', 'Population, total',
#        'Population growth (annual %)',
#        'Life expectancy at birth, total (years)',
#        'Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)'],
#       dtype='object')

# %% [markdown]
# **Toplam rezervler (altın, cari ABD doları)

# %%
plt_1 = plt.figure(figsize=(10,8))
plt.xlabel('Year')
plt.ylabel('Total reserves (includes gold, current US$)')
plt.title('Total reserves (includes gold, current US$) per year')
plt.bar(df['Year'],df['Total reserves (includes gold, current US$)'])
# Out:
# <BarContainer object of 180 artists>

# %% [markdown]
# **Nüfus, yıllık toplam

# %%
plt_1 = plt.figure(figsize=(10,8))
plt.xlabel('Year')
plt.ylabel('Population, total')
plt.title('Population, total per year')
plt.scatter(df['Year'],df['Population, total'])

# %% [markdown]
# **Nüfus, yıllık toplam

# %%
plt_1 = plt.figure(figsize=(10,8))
plt.xlabel('Year')
plt.ylabel('Population, total')
plt.title('Population, total per year')
plt.bar(df['Year'],df['Unemployment, total (% of total labor force) (modeled ILO estimate)'])
# Out:
# <BarContainer object of 180 artists>

# %%
req_cols=['Country Name','Year','GDP (current US$)','GDP, PPP (current international $)',
              'GDP per capita (current US$)','GDP growth (annual %)','Imports of goods and services (% of GDP)',
              'Exports of goods and services (% of GDP)','Central government debt, total (% of GDP)',
              'Total reserves (includes gold, current US$)',
              'Unemployment, total (% of total labor force) (modeled ILO estimate)',
              'Inflation, consumer prices (annual %)',
              'Personal remittances, received (% of GDP)',
              'Population, total','Population growth (annual %)',
              'Life expectancy at birth, total (years)',
              'Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)']

# %%
def preprocessed_df(csvfile):
    
    #load csv file as pandas dataframe
    df=pd.read_csv(csvfile)
    
    #select the country name column as pandas series
    country_name=pd.Series(df["Country Name"].iloc[33:63])
    
    #Renaming "Indicator Name" column into "Year"
    df.rename(columns = {'Indicator Name':'Year'}, inplace = True)
    
    #Droping "Country Name" and "Country Code" columns after that transposing the whole dataframe using transpose() 
    country_df = df.drop(["Country Name","Country Code"],axis=1).transpose()
    
    #Setting the first row of the dataframe as row header 
    country_df.reset_index(inplace=True)
    new_header = country_df.iloc[0]
    country_df.columns = new_header
    
   #The raw csv file contain data from 1960 but the required data are from 1990 to 2020.Here selecting the required years
    final_df=country_df.iloc[33:63]
   
   # Finally concating the country_name series with the final_df dataframe using pandas concat() function
    return pd.concat([country_name,final_df],axis=1)
